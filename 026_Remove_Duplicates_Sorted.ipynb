# %% [markdown]
# # 26. Remove Duplicates from Sorted Array
# Given a sorted array nums, remove the duplicates in-place such that each element appear only once and return the new length.
#
# Do not allocate extra space for another array, you must do this by modifying the input array in-place with O(1) extra memory.
#
# <div class="alert alert-block alert-info">
# Example 1:
#
# Given nums = [1,1,2],
#
# Your function should return length = 2, with the first two elements of nums being 1 and 2 respectively.
#
# It doesn't matter what you leave beyond the returned length.
# </div>
#
# ## Approach 1: Two Pointers
# Algorithm
#
# Since the array is already sorted, we can keep two pointers i and j, where i is the slow-runner while j is the fast-runner. As long as nums[i] = nums[j], we increment j to skip the duplicate.
#
# When we encounter $nums[j] \neq nums[i]$, the duplicate run has ended so we must copy its value to $nums[i + 1]$. i is then incremented and we repeat the same process again until j reaches the end of array.
#
# ![remove_duplicate.gif](attachment:remove_duplicate.gif)
# https://camo.githubusercontent.com/74ae3265f10552715023aef368d9d8e15e051965/68747470733a2f2f6275636b65742d313235373132363534392e636f732e61702d6775616e677a686f752e6d7971636c6f75642e636f6d2f32303138313131363131353630312e676966

# %%
def removeDuplicates(nums):
    if not nums:
        return 0
    i,j = 0,1
    while j < len(nums):
        if nums[i] != nums[j]:
            i +=1
            # move val to i+1
            nums[i] = nums[j]
        j +=1
    return i+1

print(removeDuplicates([1,1,2]))
# Out:
# 2
