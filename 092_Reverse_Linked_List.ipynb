# %% [markdown]
# ## 92. Reverse Linked List II
#
# Reverse a linked list from position m to n. Do it in one-pass.
#
# Note: 1 ≤ m ≤ n ≤ length of list.
# <div class="alert alert-block alert-info">
# Example:
#
# Input: 1->2->3->4->5->NULL, m = 2, n = 4
#
# Output: 1->4->3->2->5->NULL
# </div>
#
#
# ![reverse_linkedlist.gif](attachment:reverse_linkedlist.gif)
# https://camo.githubusercontent.com/6a2b7395e2563c051e1f1abdf387907f16cbdf07/68747470733a2f2f6275636b65742d313235373132363534392e636f732e61702d6775616e677a686f752e6d7971636c6f75642e636f6d2f32303138313130333136303232362e676966

# %%
def reverseBetween(head: ListNode, m: int, n: int) -> ListNode:
    if m == n:
        return head
    pre = dummy = ListNode(0)
    dummy.next = head
    for _ in range(m-1):
        pre = pre.next
    # reverse the [m,n] nodes
    cur = pre.next
    reverse = None
    for _ in range(n-m+1):
        next = cur.next
        cur.next = reverse
        reverse = cur
        cur = next
    # connect m with n+1
    pre.next.next = cur
    # connect n with m-1
    pre.next = reverse

    return dummy.next
